# %%
import pandas as pd
import os

# CREATE data folder
os.makedirs('data', exist_ok=True)

# EXACT data from your files - PERFECT format
pilots_data = {
    'pilotid': ['P001', 'P002', 'P003', 'P004'],
    'name': ['Arjun', 'Neha', 'Rohit', 'Sneha'],
    'skills': ['Mapping, Survey', 'Inspection', 'Inspection, Mapping', 'Survey, Thermal'],
    'certifications': ['DGCA, Night Ops', 'DGCA', 'DGCA', 'DGCA, Night Ops'],
    'location': ['Bangalore', 'Mumbai', 'Mumbai', 'Bangalore'],
    'status': ['Available', 'Assigned', 'Available', 'On Leave'],
    'currentassignment': ['-', 'Project-A', '-', '-'],
    'availablefrom': ['2026-02-05', '2026-02-12', '2026-02-05', '2026-02-15'],
    'dailyrateinr': [1500, 3000, 1500, 5000]
}

drones_data = {
    'droneid': ['D001', 'D002', 'D003', 'D004'],
    'model': ['DJI M300', 'DJI Mavic 3', 'DJI Mavic 3T', 'Autel Evo II'],
    'capabilities': ['LiDAR, RGB', 'RGB', 'Thermal', 'Thermal, RGB'],
    'status': ['Available', 'Maintenance', 'Available', 'Available'],
    'location': ['Bangalore', 'Mumbai', 'Mumbai', 'Bangalore'],
    'currentassignment': ['-', '-', '-', '-'],
    'maintenancedue': ['2026-03-01', '2026-02-01', '2026-04-01', '2026-03-15'],
    'weatherresistance': ['IP43 Rain', 'None Clear Sky Only', 'IP43 Rain', 'None Clear Sky Only']
}

missions_data = {
    'projectid': ['PRJ001', 'PRJ002', 'PRJ003'],
    'client': ['Client A', 'Client B', 'Client C'],
    'location': ['Bangalore', 'Mumbai', 'Bangalore'],
    'requiredskills': ['Mapping', 'Inspection', 'Thermal'],
    'requiredcerts': ['DGCA', 'DGCA, Night Ops', 'DGCA'],
    'startdate': ['2026-02-06', '2026-02-07', '2026-02-10'],
    'enddate': ['2026-02-08', '2026-02-09', '2026-02-12'],
    'priority': ['High', 'Urgent', 'Standard'],
    'missionbudgetinr': [10500, 10500, 10500],
    'weatherforecast': ['Rainy', 'Sunny', 'Cloudy']
}

# Save PERFECT CSVs
pd.DataFrame(pilots_data).to_csv('data/pilot_roster.csv', index=False)
pd.DataFrame(drones_data).to_csv('data/drone_fleet.csv', index=False)
pd.DataFrame(missions_data).to_csv('data/missions.csv', index=False)

print(" DATA CREATED!")
print("Pilots shape:", pd.read_csv('data/pilot_roster.csv').shape)
print("Drones shape:", pd.read_csv('data/drone_fleet.csv').shape)
print("Missions shape:", pd.read_csv('data/missions.csv').shape)
# Out:
#  DATA CREATED!
# Pilots shape: (4, 9)
# Drones shape: (4, 8)
# Missions shape: (3, 10)
